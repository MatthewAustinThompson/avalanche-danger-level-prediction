# %% [markdown]
# # Feature Engineering

# %% [markdown]
# I will be creating features that hold that past few days of data for each variable to hopefully increase model robustness

# %% [markdown]
# ## Import Tools

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn 
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA

# pandas
from pandas.plotting import scatter_matrix

# %%
avi = pd.read_csv('SnowWeatherClean.csv')
print(avi)
# Out:
#       Unnamed: 0  avi_danger   avg_wind  temp_max_swing  \
# 0              0         2.0  10.740000             0.0
# 1              1         1.0   9.400000             3.0
# 2              2         1.0  20.580000             0.0
# 3              3         3.0  35.120000             3.0
# 4              4         2.0  33.780000            -3.0
# ...          ...         ...        ...             ...
# 1248        1248         1.0  27.125000            13.0
# 1249        1249         3.0  28.500000             2.0
# 1250        1250         3.0  11.833333            -1.0
# 1251        1251         3.0  24.416667             8.0
# 1252        1252         2.0  56.875000            -5.0
#
#       temp_max_swing_from_avg    year  month   day  temp_max  temp_min  ...  \
# 0                         0.0  2010.0   12.0  18.0        12         4  ...
# 1                         0.0  2010.0   12.0  19.0        15         3  ...
# 2                         0.0  2010.0   12.0  20.0        15         5  ...
# 3                         0.0  2010.0   12.0  21.0        18        10  ...
# 4                         0.0  2010.0   12.0  22.0        15         7  ...
# ...                       ...     ...    ...   ...       ...       ...  ...
# 1248                     -3.0  2020.0    3.0  23.0        25         1  ...
# 1249                     -1.4  2020.0    3.0  24.0        25         9  ...
# 1250                     -0.2  2020.0    3.0  25.0        24         9  ...
# 1251                     11.6  2020.0    3.0  26.0        32        20  ...
# 1252                      4.2  2020.0    3.0  27.0        27        11  ...
#
#       northwest_wind_hours  prevailing_wind_E  prevailing_wind_N  \
# 0                       12                  0                  0
# 1                       12                  0                  0
# 2                        0                  0                  1
# 3                        0                  0                  1
# 4                        1                  0                  1
# ...                    ...                ...                ...
# 1248                     0                  0                  0
# 1249                    13                  0                  0
# 1250                     2                  0                  0
# 1251                     4                  0                  1
# 1252                    19                  0                  0
#
#       prevailing_wind_NE  prevailing_wind_NW  prevailing_wind_S  \
# 0                      0                   1                  0
# 1                      0                   1                  0
# 2                      0                   0                  0
# 3                      0                   0                  0
# 4                      0                   0                  0
# ...                  ...                 ...                ...
# 1248                   0                   0                  1
# 1249                   0                   1                  0
# 1250                   0                   0                  0
# 1251                   0                   0                  0
# 1252                   0                   1                  0
#
#       prevailing_wind_SE  prevailing_wind_SW  prevailing_wind_W  \
# 0                      0                   0                  0
# 1                      0                   0                  0
# 2                      0                   0                  0
# 3                      0                   0                  0
# 4                      0                   0                  0
# ...                  ...                 ...                ...
# 1248                   0                   0                  0
# 1249                   0                   0                  0
# 1250                   1                   0                  0
# 1251                   0                   0                  0
# 1252                   0                   0                  0
#
#       next_day_avi_danger
# 0                     1.0
# 1                     1.0
# 2                     3.0
# 3                     2.0
# 4                     3.0
# ...                   ...
# 1248                  3.0
# 1249                  3.0
# 1250                  3.0
# 1251                  2.0
# 1252                  1.0
#
# [1253 rows x 26 columns]

# %% [markdown]
# ## Dataset at a Glance

# %%
avi.describe()
# Out:
#         Unnamed: 0   avi_danger     avg_wind  temp_max_swing  \
# count  1253.000000  1253.000000  1253.000000      1253.00000
# mean    626.000000     2.088587    43.398746        -0.03352
# std     361.854252     0.888858    16.512870        11.28772
# min       0.000000     1.000000     4.250000       -44.00000
# 25%     313.000000     1.000000    31.090000        -5.00000
# 50%     626.000000     2.000000    43.400000         1.00000
# 75%     939.000000     3.000000    55.480000         7.00000
# max    1252.000000     5.000000   110.060000        39.00000
#
#        temp_max_swing_from_avg         year        month          day  \
# count              1253.000000  1253.000000  1253.000000  1253.000000
# mean                 -0.056345  2015.587390     3.499601    16.616919
# std                  13.006894     2.960021     3.110999     8.432409
# min                 -53.800000  2010.000000     1.000000     1.000000
# 25%                  -8.400000  2013.000000     2.000000    10.000000
# 50%                   0.400000  2016.000000     3.000000    17.000000
# 75%                   9.200000  2018.000000     4.000000    24.000000
# max                  34.600000  2020.000000    12.000000    31.000000
#
#           temp_max     temp_min  ...  northwest_wind_hours  prevailing_wind_E  \
# count  1253.000000  1253.000000  ...           1253.000000        1253.000000
# mean     19.794094     3.831604  ...              6.521149           0.014366
# std      14.034897    14.988959  ...              7.619898           0.119040
# min     -26.000000   -40.000000  ...              0.000000           0.000000
# 25%      11.000000    -7.000000  ...              0.000000           0.000000
# 50%      19.000000     5.000000  ...              3.000000           0.000000
# 75%      30.000000    13.000000  ...             11.000000           0.000000
# max      57.000000    47.000000  ...             24.000000           1.000000
#
#        prevailing_wind_N  prevailing_wind_NE  prevailing_wind_NW  \
# count        1253.000000         1253.000000         1253.000000
# mean            0.049481            0.018356            0.276137
# std             0.216957            0.134288            0.447264
# min             0.000000            0.000000            0.000000
# 25%             0.000000            0.000000            0.000000
# 50%             0.000000            0.000000            0.000000
# 75%             0.000000            0.000000            1.000000
# max             1.000000            1.000000            1.000000
#
#        prevailing_wind_S  prevailing_wind_SE  prevailing_wind_SW  \
# count        1253.000000         1253.000000         1253.000000
# mean            0.066241            0.026337            0.072626
# std             0.248802            0.160199            0.259625
# min             0.000000            0.000000            0.000000
# 25%             0.000000            0.000000            0.000000
# 50%             0.000000            0.000000            0.000000
# 75%             0.000000            0.000000            0.000000
# max             1.000000            1.000000            1.000000
#
#        prevailing_wind_W  next_day_avi_danger
# count        1253.000000          1253.000000
# mean            0.476457             2.087789
# std             0.499645             0.889387
# min             0.000000             1.000000
# 25%             0.000000             1.000000
# 50%             0.000000             2.000000
# 75%             1.000000             3.000000
# max             1.000000             5.000000
#
# [8 rows x 26 columns]

# %%
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1253 non-null   int64
#  1   avi_danger               1253 non-null   float64
#  2   avg_wind                 1253 non-null   float64
#  3   temp_max_swing           1253 non-null   float64
#  4   temp_max_swing_from_avg  1253 non-null   float64
#  5   year                     1253 non-null   float64
#  6   month                    1253 non-null   float64
#  7   day                      1253 non-null   float64
#  8   temp_max                 1253 non-null   int64
#  9   temp_min                 1253 non-null   int64
#  10  water_equivalent         1253 non-null   float64
#  11  snow_fall                1253 non-null   float64
#  12  snow_depth_6am           1253 non-null   float64
#  13  wind_speed_sum           1253 non-null   int64
#  14  sunshine_percent         1253 non-null   int64
#  15  west_wind_hours          1253 non-null   int64
#  16  northwest_wind_hours     1253 non-null   int64
#  17  prevailing_wind_E        1253 non-null   int64
#  18  prevailing_wind_N        1253 non-null   int64
#  19  prevailing_wind_NE       1253 non-null   int64
#  20  prevailing_wind_NW       1253 non-null   int64
#  21  prevailing_wind_S        1253 non-null   int64
#  22  prevailing_wind_SE       1253 non-null   int64
#  23  prevailing_wind_SW       1253 non-null   int64
#  24  prevailing_wind_W        1253 non-null   int64
#  25  next_day_avi_danger      1253 non-null   float64
# dtypes: float64(11), int64(15)
# memory usage: 254.6 KB

# %% [markdown]
# ## Filter Dataset

# %%
avi = avi.drop(['Unnamed: 0'], axis=1)
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avi_danger               1253 non-null   float64
#  1   avg_wind                 1253 non-null   float64
#  2   temp_max_swing           1253 non-null   float64
#  3   temp_max_swing_from_avg  1253 non-null   float64
#  4   year                     1253 non-null   float64
#  5   month                    1253 non-null   float64
#  6   day                      1253 non-null   float64
#  7   temp_max                 1253 non-null   int64
#  8   temp_min                 1253 non-null   int64
#  9   water_equivalent         1253 non-null   float64
#  10  snow_fall                1253 non-null   float64
#  11  snow_depth_6am           1253 non-null   float64
#  12  wind_speed_sum           1253 non-null   int64
#  13  sunshine_percent         1253 non-null   int64
#  14  west_wind_hours          1253 non-null   int64
#  15  northwest_wind_hours     1253 non-null   int64
#  16  prevailing_wind_E        1253 non-null   int64
#  17  prevailing_wind_N        1253 non-null   int64
#  18  prevailing_wind_NE       1253 non-null   int64
#  19  prevailing_wind_NW       1253 non-null   int64
#  20  prevailing_wind_S        1253 non-null   int64
#  21  prevailing_wind_SE       1253 non-null   int64
#  22  prevailing_wind_SW       1253 non-null   int64
#  23  prevailing_wind_W        1253 non-null   int64
#  24  next_day_avi_danger      1253 non-null   float64
# dtypes: float64(11), int64(14)
# memory usage: 244.9 KB

# %% [markdown]
# ## Drop Last Day of Each Season

# %%
avi = avi.drop(index=140)    # 5/7/11 
avi = avi.drop(index=261)    # 5/4/12 
avi = avi.drop(index=351)    # 5/4/13 
avi = avi.drop(index=481)    # 4/27/14 
avi = avi.drop(index=589)    # 5/10/15 
avi = avi.drop(index=679)    # 4/16/16 
avi = avi.drop(index=811)    # 4/22/17 
avi = avi.drop(index=907)    # 4/23/18 
avi = avi.drop(index=1168)    # 4/25/19

# %% [markdown]
# ## Reset Dataframe Index

# %%
avi.reset_index(inplace=True)
avi.drop(columns=['index'], inplace=True) # Drop previous index created as column after redet_index() called
print(avi.index)
# Out:
# RangeIndex(start=0, stop=1244, step=1)

# %% [markdown]
# ## Make 3-day and 5-day snowfall variables

# %%
print(avi.index)
# Out:
# RangeIndex(start=0, stop=1244, step=1)

# %%
three_day_snow = []

for day in range(0, avi.shape[0]):
    if (day == 0):
        three_day_snow.insert(day, avi['snow_fall'][day])
    elif (day == 1):
        three_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1])
    else:
        three_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1] + avi['snow_fall'][day - 2])

# Format elements
three_day_snow = ["%.2f" % row for row in three_day_snow]
three_day_snow = [float(row) for row in three_day_snow]

# %%
avi['three_day_snow'] = three_day_snow

# %%
print(avi.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avi_danger               1244 non-null   float64
#  1   avg_wind                 1244 non-null   float64
#  2   temp_max_swing           1244 non-null   float64
#  3   temp_max_swing_from_avg  1244 non-null   float64
#  4   year                     1244 non-null   float64
#  5   month                    1244 non-null   float64
#  6   day                      1244 non-null   float64
#  7   temp_max                 1244 non-null   int64
#  8   temp_min                 1244 non-null   int64
#  9   water_equivalent         1244 non-null   float64
#  10  snow_fall                1244 non-null   float64
#  11  snow_depth_6am           1244 non-null   float64
#  12  wind_speed_sum           1244 non-null   int64
#  13  sunshine_percent         1244 non-null   int64
#  14  west_wind_hours          1244 non-null   int64
#  15  northwest_wind_hours     1244 non-null   int64
#  16  prevailing_wind_E        1244 non-null   int64
#  17  prevailing_wind_N        1244 non-null   int64
#  18  prevailing_wind_NE       1244 non-null   int64
#  19  prevailing_wind_NW       1244 non-null   int64
#  20  prevailing_wind_S        1244 non-null   int64
#  21  prevailing_wind_SE       1244 non-null   int64
#  22  prevailing_wind_SW       1244 non-null   int64
#  23  prevailing_wind_W        1244 non-null   int64
#  24  next_day_avi_danger      1244 non-null   float64
#  25  three_day_snow           1244 non-null   float64
# dtypes: float64(12), int64(14)
# memory usage: 252.8 KB
# None

# %%
five_day_snow = []

for day in range(0, avi.shape[0]):
    if (day == 0):
        five_day_snow.insert(day, avi['snow_fall'][day])
    elif (day == 1):
        five_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1])
    elif (day == 2):
        five_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1] + avi['snow_fall'][day - 2])
    elif (day == 3):
        five_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1] + avi['snow_fall'][day - 2] + \
                                    avi['snow_fall'][day - 3])
    else:
        five_day_snow.insert(day, avi['snow_fall'][day] + avi['snow_fall'][day - 1] + avi['snow_fall'][day - 2] + \
                                    avi['snow_fall'][day - 3] + avi['snow_fall'][day - 4])

# Format elements
five_day_snow = ["%.2f" % row for row in five_day_snow]
five_day_snow = [float(row) for row in five_day_snow]

# %%
avi['five_day_snow'] = five_day_snow

# %%
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avi_danger               1244 non-null   float64
#  1   avg_wind                 1244 non-null   float64
#  2   temp_max_swing           1244 non-null   float64
#  3   temp_max_swing_from_avg  1244 non-null   float64
#  4   year                     1244 non-null   float64
#  5   month                    1244 non-null   float64
#  6   day                      1244 non-null   float64
#  7   temp_max                 1244 non-null   int64
#  8   temp_min                 1244 non-null   int64
#  9   water_equivalent         1244 non-null   float64
#  10  snow_fall                1244 non-null   float64
#  11  snow_depth_6am           1244 non-null   float64
#  12  wind_speed_sum           1244 non-null   int64
#  13  sunshine_percent         1244 non-null   int64
#  14  west_wind_hours          1244 non-null   int64
#  15  northwest_wind_hours     1244 non-null   int64
#  16  prevailing_wind_E        1244 non-null   int64
#  17  prevailing_wind_N        1244 non-null   int64
#  18  prevailing_wind_NE       1244 non-null   int64
#  19  prevailing_wind_NW       1244 non-null   int64
#  20  prevailing_wind_S        1244 non-null   int64
#  21  prevailing_wind_SE       1244 non-null   int64
#  22  prevailing_wind_SW       1244 non-null   int64
#  23  prevailing_wind_W        1244 non-null   int64
#  24  next_day_avi_danger      1244 non-null   float64
#  25  three_day_snow           1244 non-null   float64
#  26  five_day_snow            1244 non-null   float64
# dtypes: float64(13), int64(14)
# memory usage: 262.5 KB

# %% [markdown]
# ## Combine danger level 5 with danger level 4 (due to lack of samples)

# %%
print(avi[avi['next_day_avi_danger'] == 5.0])
print(avi[avi['avi_danger'] == 5.0])
# Out:
#      avi_danger  avg_wind  temp_max_swing  temp_max_swing_from_avg    year  \
# 285         4.0     74.71            -1.0                     22.4  2013.0
# 736         2.0     29.08             2.0                     -1.8  2017.0
#
#      month   day  temp_max  temp_min  water_equivalent  ...  \
# 285    1.0  31.0        42        -5              1.59  ...
# 736    2.0  12.0        14         2              0.88  ...
#
#      prevailing_wind_N  prevailing_wind_NE  prevailing_wind_NW  \
# 285                  0                   0                   0
# 736                  0                   0                   0
#
#      prevailing_wind_S  prevailing_wind_SE  prevailing_wind_SW  \
# 285                  0                   0                   0
# 736                  0                   1                   0
#
#      prevailing_wind_W  next_day_avi_danger  three_day_snow  five_day_snow
# 285                  1                  5.0             1.3            6.7
# 736                  0                  5.0            15.9           18.9
#
# [2 rows x 27 columns]
#      avi_danger  avg_wind  temp_max_swing  temp_max_swing_from_avg    year  \
# 286         5.0     50.33           -36.0                    -22.6  2013.0
# 737         5.0     41.16            -2.0                     -2.0  2017.0
#
#      month   day  temp_max  temp_min  water_equivalent  ...  \
# 286    2.0   9.0         6        -9              0.47  ...
# 737    2.0  13.0        12        -3              1.08  ...
#
#      prevailing_wind_N  prevailing_wind_NE  prevailing_wind_NW  \
# 286                  0                   1                   0
# 737                  0                   0                   1
#
#      prevailing_wind_S  prevailing_wind_SE  prevailing_wind_SW  \
# 286                  0                   0                   0
# 737                  0                   0                   0
#
#      prevailing_wind_W  next_day_avi_danger  three_day_snow  five_day_snow
# 286                  0                  3.0            11.4           17.0
# 737                  0                  3.0            28.1           30.0
#
# [2 rows x 27 columns]

# %%
avi['next_day_avi_danger'] = avi['next_day_avi_danger'].replace(5.0, 4.0)
avi['avi_danger'] = avi['avi_danger'].replace(5.0, 4.0)

# %%
print(avi[avi['next_day_avi_danger'] == 5.0])
print(avi[avi['avi_danger'] == 5.0])
# Out:
# Empty DataFrame
# Columns: [avi_danger, avg_wind, temp_max_swing, temp_max_swing_from_avg, year, month, day, temp_max, temp_min, water_equivalent, snow_fall, snow_depth_6am, wind_speed_sum, sunshine_percent, west_wind_hours, northwest_wind_hours, prevailing_wind_E, prevailing_wind_N, prevailing_wind_NE, prevailing_wind_NW, prevailing_wind_S, prevailing_wind_SE, prevailing_wind_SW, prevailing_wind_W, next_day_avi_danger, three_day_snow, five_day_snow]
# Index: []
#
# [0 rows x 27 columns]
# Empty DataFrame
# Columns: [avi_danger, avg_wind, temp_max_swing, temp_max_swing_from_avg, year, month, day, temp_max, temp_min, water_equivalent, snow_fall, snow_depth_6am, wind_speed_sum, sunshine_percent, west_wind_hours, northwest_wind_hours, prevailing_wind_E, prevailing_wind_N, prevailing_wind_NE, prevailing_wind_NW, prevailing_wind_S, prevailing_wind_SE, prevailing_wind_SW, prevailing_wind_W, next_day_avi_danger, three_day_snow, five_day_snow]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Creating Features for Previous Days

# %%
avi_columns = ['avi_danger','avg_wind', 'temp_max_swing', 'temp_max_swing_from_avg', 'temp_max', 'temp_min',
               'water_equivalent','snow_fall', 'snow_depth_6am','wind_speed_sum', 'sunshine_percent', 
               'west_wind_hours', 'northwest_wind_hours', 'prevailing_wind_E', 'prevailing_wind_N', 
               'prevailing_wind_NE', 'prevailing_wind_NW', 'prevailing_wind_S', 'prevailing_wind_SE', 
               'prevailing_wind_SW', 'prevailing_wind_W', 'three_day_snow', 'five_day_snow']

avi_columns_1 = ['avi_danger_1','avg_wind_1', 'temp_max_swing_1', 'temp_max_swing_from_avg_1', 'temp_max_1',
                 'temp_min_1', 'water_equivalent_1','snow_fall_1', 'snow_depth_6am_1','wind_speed_sum_1',
                 'sunshine_percent_1', 'west_wind_hours_1', 'northwest_wind_hours_1', 'prevailing_wind_E_1', 
                 'prevailing_wind_N_1', 'prevailing_wind_NE_1', 'prevailing_wind_NW_1', 'prevailing_wind_S_1',  
                 'prevailing_wind_SE_1', 'prevailing_wind_SW_1', 'prevailing_wind_W_1', 'three_day_snow_1', 
                 'five_day_snow_1']

avi_columns_2 = ['avi_danger_2','avg_wind_2', 'temp_max_swing_2', 'temp_max_swing_from_avg_2', 'temp_max_2',
                 'temp_min_2', 'water_equivalent_2','snow_fall_2', 'snow_depth_6am_2','wind_speed_sum_2',
                 'sunshine_percent_2', 'west_wind_hours_2', 'northwest_wind_hours_2', 'prevailing_wind_E_2', 
                 'prevailing_wind_N_2', 'prevailing_wind_NE_2', 'prevailing_wind_NW_2', 'prevailing_wind_S_2',  
                 'prevailing_wind_SE_2', 'prevailing_wind_SW_2', 'prevailing_wind_W_2', 'three_day_snow_2', 
                 'five_day_snow_2']

# %% [markdown]
# ### 1-Day Ago

# %%
temp = np.array([])
for column in range(0, len(avi_columns)):
    for row in range(0, avi.shape[0]):
        if (row == 0):
            temp = np.append(temp, np.nan)
        else:
            temp = np.append(temp, avi[avi_columns[column]][row - 1])  
    temp = np.reshape(temp, [avi.shape[0], 1])
    avi[avi_columns_1[column]] = temp
    temp = np.array([])
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 50 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   avi_danger                 1244 non-null   float64
#  1   avg_wind                   1244 non-null   float64
#  2   temp_max_swing             1244 non-null   float64
#  3   temp_max_swing_from_avg    1244 non-null   float64
#  4   year                       1244 non-null   float64
#  5   month                      1244 non-null   float64
#  6   day                        1244 non-null   float64
#  7   temp_max                   1244 non-null   int64
#  8   temp_min                   1244 non-null   int64
#  9   water_equivalent           1244 non-null   float64
#  10  snow_fall                  1244 non-null   float64
#  11  snow_depth_6am             1244 non-null   float64
#  12  wind_speed_sum             1244 non-null   int64
#  13  sunshine_percent           1244 non-null   int64
#  14  west_wind_hours            1244 non-null   int64
#  15  northwest_wind_hours       1244 non-null   int64
#  16  prevailing_wind_E          1244 non-null   int64
#  17  prevailing_wind_N          1244 non-null   int64
#  18  prevailing_wind_NE         1244 non-null   int64
#  19  prevailing_wind_NW         1244 non-null   int64
#  20  prevailing_wind_S          1244 non-null   int64
#  21  prevailing_wind_SE         1244 non-null   int64
#  22  prevailing_wind_SW         1244 non-null   int64
#  23  prevailing_wind_W          1244 non-null   int64
#  24  next_day_avi_danger        1244 non-null   float64
#  25  three_day_snow             1244 non-null   float64
#  26  five_day_snow              1244 non-null   float64
#  27  avi_danger_1               1243 non-null   float64
#  28  avg_wind_1                 1243 non-null   float64
#  29  temp_max_swing_1           1243 non-null   float64
#  30  temp_max_swing_from_avg_1  1243 non-null   float64
#  31  temp_max_1                 1243 non-null   float64
#  32  temp_min_1                 1243 non-null   float64
#  33  water_equivalent_1         1243 non-null   float64
#  34  snow_fall_1                1243 non-null   float64
#  35  snow_depth_6am_1           1243 non-null   float64
#  36  wind_speed_sum_1           1243 non-null   float64
#  37  sunshine_percent_1         1243 non-null   float64
#  38  west_wind_hours_1          1243 non-null   float64
#  39  northwest_wind_hours_1     1243 non-null   float64
#  40  prevailing_wind_E_1        1243 non-null   float64
#  41  prevailing_wind_N_1        1243 non-null   float64
#  42  prevailing_wind_NE_1       1243 non-null   float64
#  43  prevailing_wind_NW_1       1243 non-null   float64
#  44  prevailing_wind_S_1        1243 non-null   float64
#  45  prevailing_wind_SE_1       1243 non-null   float64
#  46  prevailing_wind_SW_1       1243 non-null   float64
#  47  prevailing_wind_W_1        1243 non-null   float64
#  48  three_day_snow_1           1243 non-null   float64
#  49  five_day_snow_1            1243 non-null   float64
# dtypes: float64(36), int64(14)
# memory usage: 486.1 KB

# %% [markdown]
# ### 2-Days Ago

# %%
temp = np.array([])
for column in range(0, len(avi_columns)):
    for row in range(0, avi.shape[0]):
        if (row < 2):
            temp = np.append(temp, np.nan)
        else:
            temp = np.append(temp, avi[avi_columns[column]][row - 2])  
    temp = np.reshape(temp, [avi.shape[0], 1])
    avi[avi_columns_2[column]] = temp
    temp = np.array([])
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1244 entries, 0 to 1243
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   avi_danger                 1244 non-null   float64
#  1   avg_wind                   1244 non-null   float64
#  2   temp_max_swing             1244 non-null   float64
#  3   temp_max_swing_from_avg    1244 non-null   float64
#  4   year                       1244 non-null   float64
#  5   month                      1244 non-null   float64
#  6   day                        1244 non-null   float64
#  7   temp_max                   1244 non-null   int64
#  8   temp_min                   1244 non-null   int64
#  9   water_equivalent           1244 non-null   float64
#  10  snow_fall                  1244 non-null   float64
#  11  snow_depth_6am             1244 non-null   float64
#  12  wind_speed_sum             1244 non-null   int64
#  13  sunshine_percent           1244 non-null   int64
#  14  west_wind_hours            1244 non-null   int64
#  15  northwest_wind_hours       1244 non-null   int64
#  16  prevailing_wind_E          1244 non-null   int64
#  17  prevailing_wind_N          1244 non-null   int64
#  18  prevailing_wind_NE         1244 non-null   int64
#  19  prevailing_wind_NW         1244 non-null   int64
#  20  prevailing_wind_S          1244 non-null   int64
#  21  prevailing_wind_SE         1244 non-null   int64
#  22  prevailing_wind_SW         1244 non-null   int64
#  23  prevailing_wind_W          1244 non-null   int64
#  24  next_day_avi_danger        1244 non-null   float64
#  25  three_day_snow             1244 non-null   float64
#  26  five_day_snow              1244 non-null   float64
#  27  avi_danger_1               1243 non-null   float64
#  28  avg_wind_1                 1243 non-null   float64
#  29  temp_max_swing_1           1243 non-null   float64
#  30  temp_max_swing_from_avg_1  1243 non-null   float64
#  31  temp_max_1                 1243 non-null   float64
#  32  temp_min_1                 1243 non-null   float64
#  33  water_equivalent_1         1243 non-null   float64
#  34  snow_fall_1                1243 non-null   float64
#  35  snow_depth_6am_1           1243 non-null   float64
#  36  wind_speed_sum_1           1243 non-null   float64
#  37  sunshine_percent_1         1243 non-null   float64
#  38  west_wind_hours_1          1243 non-null   float64
#  39  northwest_wind_hours_1     1243 non-null   float64
#  40  prevailing_wind_E_1        1243 non-null   float64
#  41  prevailing_wind_N_1        1243 non-null   float64
#  42  prevailing_wind_NE_1       1243 non-null   float64
#  43  prevailing_wind_NW_1       1243 non-null   float64
#  44  prevailing_wind_S_1        1243 non-null   float64
#  45  prevailing_wind_SE_1       1243 non-null   float64
#  46  prevailing_wind_SW_1       1243 non-null   float64
#  47  prevailing_wind_W_1        1243 non-null   float64
#  48  three_day_snow_1           1243 non-null   float64
#  49  five_day_snow_1            1243 non-null   float64
#  50  avi_danger_2               1242 non-null   float64
#  51  avg_wind_2                 1242 non-null   float64
#  52  temp_max_swing_2           1242 non-null   float64
#  53  temp_max_swing_from_avg_2  1242 non-null   float64
#  54  temp_max_2                 1242 non-null   float64
#  55  temp_min_2                 1242 non-null   float64
#  56  water_equivalent_2         1242 non-null   float64
#  57  snow_fall_2                1242 non-null   float64
#  58  snow_depth_6am_2           1242 non-null   float64
#  59  wind_speed_sum_2           1242 non-null   float64
#  60  sunshine_percent_2         1242 non-null   float64
#  61  west_wind_hours_2          1242 non-null   float64
#  62  northwest_wind_hours_2     1242 non-null   float64
#  63  prevailing_wind_E_2        1242 non-null   float64
#  64  prevailing_wind_N_2        1242 non-null   float64
#  65  prevailing_wind_NE_2       1242 non-null   float64
#  66  prevailing_wind_NW_2       1242 non-null   float64
#  67  prevailing_wind_S_2        1242 non-null   float64
#  68  prevailing_wind_SE_2       1242 non-null   float64
#  69  prevailing_wind_SW_2       1242 non-null   float64
#  70  prevailing_wind_W_2        1242 non-null   float64
#  71  three_day_snow_2           1242 non-null   float64
#  72  five_day_snow_2            1242 non-null   float64
# dtypes: float64(59), int64(14)
# memory usage: 709.6 KB

# %%
avi.dropna(inplace=True)

# %%
target = avi['next_day_avi_danger']
avi.drop(['next_day_avi_danger'], axis=1, inplace=True)
avi['next_day_avi_danger'] = target

# %%
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1242 entries, 2 to 1243
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   avi_danger                 1242 non-null   float64
#  1   avg_wind                   1242 non-null   float64
#  2   temp_max_swing             1242 non-null   float64
#  3   temp_max_swing_from_avg    1242 non-null   float64
#  4   year                       1242 non-null   float64
#  5   month                      1242 non-null   float64
#  6   day                        1242 non-null   float64
#  7   temp_max                   1242 non-null   int64
#  8   temp_min                   1242 non-null   int64
#  9   water_equivalent           1242 non-null   float64
#  10  snow_fall                  1242 non-null   float64
#  11  snow_depth_6am             1242 non-null   float64
#  12  wind_speed_sum             1242 non-null   int64
#  13  sunshine_percent           1242 non-null   int64
#  14  west_wind_hours            1242 non-null   int64
#  15  northwest_wind_hours       1242 non-null   int64
#  16  prevailing_wind_E          1242 non-null   int64
#  17  prevailing_wind_N          1242 non-null   int64
#  18  prevailing_wind_NE         1242 non-null   int64
#  19  prevailing_wind_NW         1242 non-null   int64
#  20  prevailing_wind_S          1242 non-null   int64
#  21  prevailing_wind_SE         1242 non-null   int64
#  22  prevailing_wind_SW         1242 non-null   int64
#  23  prevailing_wind_W          1242 non-null   int64
#  24  three_day_snow             1242 non-null   float64
#  25  five_day_snow              1242 non-null   float64
#  26  avi_danger_1               1242 non-null   float64
#  27  avg_wind_1                 1242 non-null   float64
#  28  temp_max_swing_1           1242 non-null   float64
#  29  temp_max_swing_from_avg_1  1242 non-null   float64
#  30  temp_max_1                 1242 non-null   float64
#  31  temp_min_1                 1242 non-null   float64
#  32  water_equivalent_1         1242 non-null   float64
#  33  snow_fall_1                1242 non-null   float64
#  34  snow_depth_6am_1           1242 non-null   float64
#  35  wind_speed_sum_1           1242 non-null   float64
#  36  sunshine_percent_1         1242 non-null   float64
#  37  west_wind_hours_1          1242 non-null   float64
#  38  northwest_wind_hours_1     1242 non-null   float64
#  39  prevailing_wind_E_1        1242 non-null   float64
#  40  prevailing_wind_N_1        1242 non-null   float64
#  41  prevailing_wind_NE_1       1242 non-null   float64
#  42  prevailing_wind_NW_1       1242 non-null   float64
#  43  prevailing_wind_S_1        1242 non-null   float64
#  44  prevailing_wind_SE_1       1242 non-null   float64
#  45  prevailing_wind_SW_1       1242 non-null   float64
#  46  prevailing_wind_W_1        1242 non-null   float64
#  47  three_day_snow_1           1242 non-null   float64
#  48  five_day_snow_1            1242 non-null   float64
#  49  avi_danger_2               1242 non-null   float64
#  50  avg_wind_2                 1242 non-null   float64
#  51  temp_max_swing_2           1242 non-null   float64
#  52  temp_max_swing_from_avg_2  1242 non-null   float64
#  53  temp_max_2                 1242 non-null   float64
#  54  temp_min_2                 1242 non-null   float64
#  55  water_equivalent_2         1242 non-null   float64
#  56  snow_fall_2                1242 non-null   float64
#  57  snow_depth_6am_2           1242 non-null   float64
#  58  wind_speed_sum_2           1242 non-null   float64
#  59  sunshine_percent_2         1242 non-null   float64
#  60  west_wind_hours_2          1242 non-null   float64
#  61  northwest_wind_hours_2     1242 non-null   float64
#  62  prevailing_wind_E_2        1242 non-null   float64
#  63  prevailing_wind_N_2        1242 non-null   float64
#  64  prevailing_wind_NE_2       1242 non-null   float64
#  65  prevailing_wind_NW_2       1242 non-null   float64
#  66  prevailing_wind_S_2        1242 non-null   float64
#  67  prevailing_wind_SE_2       1242 non-null   float64
#  68  prevailing_wind_SW_2       1242 non-null   float64
#  69  prevailing_wind_W_2        1242 non-null   float64
#  70  three_day_snow_2           1242 non-null   float64
#  71  five_day_snow_2            1242 non-null   float64
#  72  next_day_avi_danger        1242 non-null   float64
# dtypes: float64(59), int64(14)
# memory usage: 718.0 KB

# %% [markdown]
# ## Drop First 2 Days of Each Season

# %%
avi = avi.drop(index=138)    # 1/5/12
avi = avi.drop(index=139)    # 1/6/12
avi = avi.drop(index=258)    # 12/26/12
avi = avi.drop(index=259)    # 12/27/12
avi = avi.drop(index=347)    # 12/15/13
avi = avi.drop(index=348)    # 12/16/13
avi = avi.drop(index=476)    # 12/13/14
avi = avi.drop(index=477)    # 12/14/14
avi = avi.drop(index=583)    # 1/18/16
avi = avi.drop(index=584)    # 1/19/16
avi = avi.drop(index=672)    # 12/9/16
avi = avi.drop(index=673)    # 12/10/16
avi = avi.drop(index=803)    # 12/12/17
avi = avi.drop(index=804)    # 12/13/17
avi = avi.drop(index=898)    # 11/27/18
avi = avi.drop(index=899)    # 11/18/18
avi = avi.drop(index=1158)    # 1/4/20
avi = avi.drop(index=1159)    # 1/5/20

# %% [markdown]
# ## Reset DataFrame Index

# %%
avi.reset_index(inplace=True)
avi.drop(columns=['index'], inplace=True) # Drop previous index created as column after redet_index() called
print(avi.index)
# Out:
# RangeIndex(start=0, stop=1224, step=1)

# %% [markdown]
# ## Export to CSV

# %%
avi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 73 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   avi_danger                 1224 non-null   float64
#  1   avg_wind                   1224 non-null   float64
#  2   temp_max_swing             1224 non-null   float64
#  3   temp_max_swing_from_avg    1224 non-null   float64
#  4   year                       1224 non-null   float64
#  5   month                      1224 non-null   float64
#  6   day                        1224 non-null   float64
#  7   temp_max                   1224 non-null   int64
#  8   temp_min                   1224 non-null   int64
#  9   water_equivalent           1224 non-null   float64
#  10  snow_fall                  1224 non-null   float64
#  11  snow_depth_6am             1224 non-null   float64
#  12  wind_speed_sum             1224 non-null   int64
#  13  sunshine_percent           1224 non-null   int64
#  14  west_wind_hours            1224 non-null   int64
#  15  northwest_wind_hours       1224 non-null   int64
#  16  prevailing_wind_E          1224 non-null   int64
#  17  prevailing_wind_N          1224 non-null   int64
#  18  prevailing_wind_NE         1224 non-null   int64
#  19  prevailing_wind_NW         1224 non-null   int64
#  20  prevailing_wind_S          1224 non-null   int64
#  21  prevailing_wind_SE         1224 non-null   int64
#  22  prevailing_wind_SW         1224 non-null   int64
#  23  prevailing_wind_W          1224 non-null   int64
#  24  three_day_snow             1224 non-null   float64
#  25  five_day_snow              1224 non-null   float64
#  26  avi_danger_1               1224 non-null   float64
#  27  avg_wind_1                 1224 non-null   float64
#  28  temp_max_swing_1           1224 non-null   float64
#  29  temp_max_swing_from_avg_1  1224 non-null   float64
#  30  temp_max_1                 1224 non-null   float64
#  31  temp_min_1                 1224 non-null   float64
#  32  water_equivalent_1         1224 non-null   float64
#  33  snow_fall_1                1224 non-null   float64
#  34  snow_depth_6am_1           1224 non-null   float64
#  35  wind_speed_sum_1           1224 non-null   float64
#  36  sunshine_percent_1         1224 non-null   float64
#  37  west_wind_hours_1          1224 non-null   float64
#  38  northwest_wind_hours_1     1224 non-null   float64
#  39  prevailing_wind_E_1        1224 non-null   float64
#  40  prevailing_wind_N_1        1224 non-null   float64
#  41  prevailing_wind_NE_1       1224 non-null   float64
#  42  prevailing_wind_NW_1       1224 non-null   float64
#  43  prevailing_wind_S_1        1224 non-null   float64
#  44  prevailing_wind_SE_1       1224 non-null   float64
#  45  prevailing_wind_SW_1       1224 non-null   float64
#  46  prevailing_wind_W_1        1224 non-null   float64
#  47  three_day_snow_1           1224 non-null   float64
#  48  five_day_snow_1            1224 non-null   float64
#  49  avi_danger_2               1224 non-null   float64
#  50  avg_wind_2                 1224 non-null   float64
#  51  temp_max_swing_2           1224 non-null   float64
#  52  temp_max_swing_from_avg_2  1224 non-null   float64
#  53  temp_max_2                 1224 non-null   float64
#  54  temp_min_2                 1224 non-null   float64
#  55  water_equivalent_2         1224 non-null   float64
#  56  snow_fall_2                1224 non-null   float64
#  57  snow_depth_6am_2           1224 non-null   float64
#  58  wind_speed_sum_2           1224 non-null   float64
#  59  sunshine_percent_2         1224 non-null   float64
#  60  west_wind_hours_2          1224 non-null   float64
#  61  northwest_wind_hours_2     1224 non-null   float64
#  62  prevailing_wind_E_2        1224 non-null   float64
#  63  prevailing_wind_N_2        1224 non-null   float64
#  64  prevailing_wind_NE_2       1224 non-null   float64
#  65  prevailing_wind_NW_2       1224 non-null   float64
#  66  prevailing_wind_S_2        1224 non-null   float64
#  67  prevailing_wind_SE_2       1224 non-null   float64
#  68  prevailing_wind_SW_2       1224 non-null   float64
#  69  prevailing_wind_W_2        1224 non-null   float64
#  70  three_day_snow_2           1224 non-null   float64
#  71  five_day_snow_2            1224 non-null   float64
#  72  next_day_avi_danger        1224 non-null   float64
# dtypes: float64(59), int64(14)
# memory usage: 698.2 KB

# %%
avi.to_csv('SnowWeatherCleanFE.csv')
